# %%
import random
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []


# Identify nearest city for each latitude and longitude combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 741

# %%
# Import the requests library.
import requests

# %%
from config import weather_api_key

# %%
# API Call with openweathermap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library.
import time
from datetime import datetime

# %%
# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S') 
        city_description = city_weather["weather"][0]["description"]


        # Append the City information into city_data list
        city_data.append({"City": city.title(), 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_description})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 2 of Set 1 | kilembe
# Processing Record 3 of Set 1 | quelimane
# Processing Record 4 of Set 1 | cape town
# Processing Record 5 of Set 1 | nova olinda do norte
# Processing Record 6 of Set 1 | novopokrovka
# Processing Record 7 of Set 1 | meulaboh
# Processing Record 8 of Set 1 | ahipara
# Processing Record 9 of Set 1 | kruisfontein
# Processing Record 10 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 1 | tiksi
# Processing Record 12 of Set 1 | bluff
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | qaanaaq
# Processing Record 15 of Set 1 | castro
# Processing Record 16 of Set 1 | lambarene
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | barrow
# Processing Record 19 of Set 1 | puerto ayora
# Processing Record 20 of Set 1 | tilichiki
# Processing Record 21 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 1 | douglas
# Processing Record 23 of Set 1 | atuona
# Processing Record 24 of Set 1 | puerto carreno
# Processing Record 25 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 26 of Set 1 | zhireken
# Processing Record 27 of Set 1 | grindavik
# Processing Record 28 of Set 1 | ust-ishim
# Processing Record 29 of Set 1 | parsabad
# Processing Record 30 of Set 1 | cidreira
# Processing Record 31 of Set 1 | hobart
# Processing Record 32 of Set 1 | hermanus
# Processing Record 33 of Set 1 | xining
# Processing Record 34 of Set 1 | cherskiy
# Processing Record 35 of Set 1 | shar
# Processing Record 36 of Set 1 | new norfolk
# Processing Record 37 of Set 1 | nongstoin
# Processing Record 38 of Set 1 | bargal
# City not found. Skipping...
# Processing Record 39 of Set 1 | busselton
# Processing Record 40 of Set 1 | batemans bay
# Processing Record 41 of Set 1 | henties bay
# Processing Record 42 of Set 1 | mataura
# Processing Record 43 of Set 1 | tessalit
# Processing Record 44 of Set 1 | takoradi
# Processing Record 45 of Set 1 | maniitsoq
# Processing Record 46 of Set 1 | chokurdakh
# Processing Record 47 of Set 1 | rikitea
# Processing Record 48 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 49 of Set 1 | mar del plata
# Processing Record 50 of Set 1 | kyren
# Processing Record 1 of Set 2 | khatanga
# Processing Record 2 of Set 2 | mirina
# City not found. Skipping...
# Processing Record 3 of Set 2 | urumqi
# Processing Record 4 of Set 2 | salalah
# Processing Record 5 of Set 2 | thompson
# Processing Record 6 of Set 2 | vaini
# Processing Record 7 of Set 2 | verkhoyansk
# Processing Record 8 of Set 2 | bacolod
# Processing Record 9 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 2 | dikson
# Processing Record 11 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 2 | lubango
# Processing Record 13 of Set 2 | lebu
# Processing Record 14 of Set 2 | victoria
# Processing Record 15 of Set 2 | mahebourg
# Processing Record 16 of Set 2 | miami
# Processing Record 17 of Set 2 | bumba
# Processing Record 18 of Set 2 | kalomo
# City not found. Skipping...
# Processing Record 19 of Set 2 | saint-philippe
# Processing Record 20 of Set 2 | jamestown
# Processing Record 21 of Set 2 | port alfred
# Processing Record 22 of Set 2 | berlevag
# Processing Record 23 of Set 2 | padang
# Processing Record 24 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 25 of Set 2 | ishikari
# Processing Record 26 of Set 2 | kaeo
# Processing Record 27 of Set 2 | puerto quijarro
# Processing Record 28 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 29 of Set 2 | georgetown
# Processing Record 30 of Set 2 | clyde river
# Processing Record 31 of Set 2 | ossora
# Processing Record 32 of Set 2 | vila velha
# Processing Record 33 of Set 2 | prinos
# Processing Record 34 of Set 2 | kenai
# Processing Record 35 of Set 2 | vrangel
# Processing Record 36 of Set 2 | bredasdorp
# Processing Record 37 of Set 2 | comodoro rivadavia
# Processing Record 38 of Set 2 | semey
# Processing Record 39 of Set 2 | homer
# Processing Record 40 of Set 2 | buraydah
# Processing Record 41 of Set 2 | shimoda
# Processing Record 42 of Set 2 | oxapampa
# Processing Record 43 of Set 2 | teya
# Processing Record 44 of Set 2 | mehamn
# Processing Record 45 of Set 2 | sulangan
# Processing Record 46 of Set 2 | sept-iles
# Processing Record 47 of Set 2 | aflu
# City not found. Skipping...
# Processing Record 48 of Set 2 | albany
# Processing Record 49 of Set 2 | kodiak
# Processing Record 50 of Set 2 | ust-kuyga
# Processing Record 1 of Set 3 | cabo san lucas
# Processing Record 2 of Set 3 | ribeira grande
# Processing Record 3 of Set 3 | poum
# Processing Record 4 of Set 3 | butaritari
# Processing Record 5 of Set 3 | kalaleh
# Processing Record 6 of Set 3 | tuktoyaktuk
# Processing Record 7 of Set 3 | nouakchott
# Processing Record 8 of Set 3 | fortuna
# Processing Record 9 of Set 3 | kapaa
# Processing Record 10 of Set 3 | souillac
# Processing Record 11 of Set 3 | palasa
# Processing Record 12 of Set 3 | tecolutla
# Processing Record 13 of Set 3 | varaklani
# City not found. Skipping...
# Processing Record 14 of Set 3 | codrington
# Processing Record 15 of Set 3 | bethel
# Processing Record 16 of Set 3 | carnarvon
# Processing Record 17 of Set 3 | javanrud
# Processing Record 18 of Set 3 | yulara
# Processing Record 19 of Set 3 | yellowknife
# Processing Record 20 of Set 3 | provideniya
# Processing Record 21 of Set 3 | pevek
# Processing Record 22 of Set 3 | chilchota
# Processing Record 23 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 24 of Set 3 | kavieng
# Processing Record 25 of Set 3 | nizhniy kuranakh
# Processing Record 26 of Set 3 | gilgit
# Processing Record 27 of Set 3 | lipin bor
# Processing Record 28 of Set 3 | nishihara
# Processing Record 29 of Set 3 | gizo
# Processing Record 30 of Set 3 | polunochnoye
# Processing Record 31 of Set 3 | sirohi
# Processing Record 32 of Set 3 | gat
# Processing Record 33 of Set 3 | alotau
# City not found. Skipping...
# Processing Record 34 of Set 3 | puerto escondido
# Processing Record 35 of Set 3 | aasiaat
# Processing Record 36 of Set 3 | skjervoy
# Processing Record 37 of Set 3 | ajjampur
# Processing Record 38 of Set 3 | varnavino
# Processing Record 39 of Set 3 | sarangani
# Processing Record 40 of Set 3 | port blair
# Processing Record 41 of Set 3 | solnechnyy
# Processing Record 42 of Set 3 | havre-saint-pierre
# Processing Record 43 of Set 3 | banjar
# Processing Record 44 of Set 3 | miri
# Processing Record 45 of Set 3 | arraial do cabo
# Processing Record 46 of Set 3 | llandrindod wells
# Processing Record 47 of Set 3 | nipawin
# Processing Record 48 of Set 3 | mokhsogollokh
# Processing Record 49 of Set 3 | edeia
# Processing Record 50 of Set 3 | ulaanbaatar
# Processing Record 1 of Set 4 | hay river
# Processing Record 2 of Set 4 | pangnirtung
# Processing Record 3 of Set 4 | mocambique
# City not found. Skipping...
# Processing Record 4 of Set 4 | kangayam
# Processing Record 5 of Set 4 | hervey bay
# Processing Record 6 of Set 4 | flinders
# Processing Record 7 of Set 4 | eirunepe
# Processing Record 8 of Set 4 | iqaluit
# Processing Record 9 of Set 4 | boa vista
# Processing Record 10 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 11 of Set 4 | doctor mora
# Processing Record 12 of Set 4 | luderitz
# Processing Record 13 of Set 4 | kirakira
# Processing Record 14 of Set 4 | riyadh
# Processing Record 15 of Set 4 | nanortalik
# Processing Record 16 of Set 4 | abnub
# Processing Record 17 of Set 4 | ponta do sol
# Processing Record 18 of Set 4 | port moresby
# Processing Record 19 of Set 4 | kungurtug
# Processing Record 20 of Set 4 | bilma
# Processing Record 21 of Set 4 | necochea
# Processing Record 22 of Set 4 | nikolskoye
# Processing Record 23 of Set 4 | joshimath
# Processing Record 24 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 25 of Set 4 | san patricio
# Processing Record 26 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 27 of Set 4 | svetlaya
# Processing Record 28 of Set 4 | leningradskiy
# Processing Record 29 of Set 4 | hithadhoo
# Processing Record 30 of Set 4 | robertsport
# Processing Record 31 of Set 4 | durban
# Processing Record 32 of Set 4 | upernavik
# Processing Record 33 of Set 4 | sitka
# Processing Record 34 of Set 4 | esperance
# Processing Record 35 of Set 4 | portree
# Processing Record 36 of Set 4 | tasiilaq
# Processing Record 37 of Set 4 | cam ranh
# Processing Record 38 of Set 4 | hilo
# Processing Record 39 of Set 4 | niltepec
# Processing Record 40 of Set 4 | velyka lepetykha
# Processing Record 41 of Set 4 | winnemucca
# Processing Record 42 of Set 4 | etchoropo
# Processing Record 43 of Set 4 | severo-kurilsk
# Processing Record 44 of Set 4 | denpasar
# Processing Record 45 of Set 4 | husavik
# Processing Record 46 of Set 4 | komsomolskiy
# Processing Record 47 of Set 4 | saldanha
# Processing Record 48 of Set 4 | monrovia
# Processing Record 49 of Set 4 | sao jose da coroa grande
# Processing Record 50 of Set 4 | airai
# Processing Record 1 of Set 5 | poya
# Processing Record 2 of Set 5 | correntina
# Processing Record 3 of Set 5 | changping
# Processing Record 4 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 5 | megion
# Processing Record 6 of Set 5 | santa lucia
# Processing Record 7 of Set 5 | nouadhibou
# Processing Record 8 of Set 5 | pisco
# Processing Record 9 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 5 | umm lajj
# Processing Record 11 of Set 5 | high level
# Processing Record 12 of Set 5 | zatoka
# Processing Record 13 of Set 5 | guerrero negro
# Processing Record 14 of Set 5 | chuy
# Processing Record 15 of Set 5 | dingle
# Processing Record 16 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 17 of Set 5 | klaksvik
# Processing Record 18 of Set 5 | coquimbo
# Processing Record 19 of Set 5 | leh
# Processing Record 20 of Set 5 | darlawn
# Processing Record 21 of Set 5 | ilulissat
# Processing Record 22 of Set 5 | methoni
# Processing Record 23 of Set 5 | kavaratti
# Processing Record 24 of Set 5 | asyut
# Processing Record 25 of Set 5 | anadyr
# Processing Record 26 of Set 5 | sambava
# Processing Record 27 of Set 5 | jalpan
# Processing Record 28 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 5 | raga
# Processing Record 30 of Set 5 | hualmay
# Processing Record 31 of Set 5 | kahului
# Processing Record 32 of Set 5 | katima mulilo
# Processing Record 33 of Set 5 | qandala
# Processing Record 34 of Set 5 | hambantota
# Processing Record 35 of Set 5 | talnakh
# Processing Record 36 of Set 5 | ciudad bolivar
# Processing Record 37 of Set 5 | porto walter
# Processing Record 38 of Set 5 | port elizabeth
# Processing Record 39 of Set 5 | strandby
# Processing Record 40 of Set 5 | sao filipe
# Processing Record 41 of Set 5 | deori khas
# Processing Record 42 of Set 5 | dauriya
# Processing Record 43 of Set 5 | sibu
# Processing Record 44 of Set 5 | longyearbyen
# Processing Record 45 of Set 5 | norman wells
# Processing Record 46 of Set 5 | bengkulu
# Processing Record 47 of Set 5 | parainen
# Processing Record 48 of Set 5 | bilibino
# Processing Record 49 of Set 5 | te anau
# Processing Record 50 of Set 5 | yenangyaung
# Processing Record 1 of Set 6 | los llanos de aridane
# Processing Record 2 of Set 6 | lavrentiya
# Processing Record 3 of Set 6 | wahran
# City not found. Skipping...
# Processing Record 4 of Set 6 | geraldton
# Processing Record 5 of Set 6 | tres arroyos
# Processing Record 6 of Set 6 | rozsypne
# Processing Record 7 of Set 6 | altay
# Processing Record 8 of Set 6 | bambous virieux
# Processing Record 9 of Set 6 | yuncheng
# Processing Record 10 of Set 6 | coffeyville
# Processing Record 11 of Set 6 | alta floresta
# Processing Record 12 of Set 6 | santa cruz
# Processing Record 13 of Set 6 | avarua
# Processing Record 14 of Set 6 | itaqui
# Processing Record 15 of Set 6 | makakilo city
# Processing Record 16 of Set 6 | joinville
# Processing Record 17 of Set 6 | mutsamudu
# City not found. Skipping...
# Processing Record 18 of Set 6 | lorengau
# Processing Record 19 of Set 6 | maragogi
# Processing Record 20 of Set 6 | acarau
# Processing Record 21 of Set 6 | yongchang
# Processing Record 22 of Set 6 | oranjestad
# Processing Record 23 of Set 6 | tazovskiy
# Processing Record 24 of Set 6 | wegrow
# Processing Record 25 of Set 6 | vestmanna
# Processing Record 26 of Set 6 | esil
# Processing Record 27 of Set 6 | saint george
# Processing Record 28 of Set 6 | zletovo
# Processing Record 29 of Set 6 | axim
# Processing Record 30 of Set 6 | mahabad
# Processing Record 31 of Set 6 | aksay
# Processing Record 32 of Set 6 | dargaville
# Processing Record 33 of Set 6 | sheridan
# Processing Record 34 of Set 6 | faya
# Processing Record 35 of Set 6 | port hardy
# Processing Record 36 of Set 6 | zhuji
# Processing Record 37 of Set 6 | olga
# Processing Record 38 of Set 6 | vanimo
# Processing Record 39 of Set 6 | bay roberts
# Processing Record 40 of Set 6 | alofi
# Processing Record 41 of Set 6 | mugur-aksy
# Processing Record 42 of Set 6 | springbok
# Processing Record 43 of Set 6 | morondava
# Processing Record 44 of Set 6 | ashukino
# Processing Record 45 of Set 6 | general roca
# Processing Record 46 of Set 6 | ketchikan
# Processing Record 47 of Set 6 | ukiah
# Processing Record 48 of Set 6 | les cayes
# Processing Record 49 of Set 6 | roebourne
# Processing Record 50 of Set 6 | batagay
# Processing Record 1 of Set 7 | trincomalee
# Processing Record 2 of Set 7 | kuzino
# Processing Record 3 of Set 7 | suriapet
# Processing Record 4 of Set 7 | luganville
# Processing Record 5 of Set 7 | lompoc
# Processing Record 6 of Set 7 | weiser
# Processing Record 7 of Set 7 | villa bruzual
# Processing Record 8 of Set 7 | gopalpur
# Processing Record 9 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 7 | kaitangata
# Processing Record 11 of Set 7 | lata
# Processing Record 12 of Set 7 | chengde
# Processing Record 13 of Set 7 | haibowan
# City not found. Skipping...
# Processing Record 14 of Set 7 | amalapuram
# Processing Record 15 of Set 7 | port hedland
# Processing Record 16 of Set 7 | westport
# Processing Record 17 of Set 7 | tocopilla
# Processing Record 18 of Set 7 | ostrovnoy
# Processing Record 19 of Set 7 | ostersund
# Processing Record 20 of Set 7 | nantucket
# Processing Record 21 of Set 7 | cayenne
# Processing Record 22 of Set 7 | katsuura
# Processing Record 23 of Set 7 | mogoytuy
# Processing Record 24 of Set 7 | redlands
# Processing Record 25 of Set 7 | erdenet
# Processing Record 26 of Set 7 | tatarsk
# Processing Record 27 of Set 7 | bontang
# Processing Record 28 of Set 7 | pedro ii
# Processing Record 29 of Set 7 | sao joao do piaui
# Processing Record 30 of Set 7 | turayf
# Processing Record 31 of Set 7 | ayorou
# Processing Record 32 of Set 7 | zachepylivka
# Processing Record 33 of Set 7 | aklavik
# Processing Record 34 of Set 7 | asino
# Processing Record 35 of Set 7 | newport
# Processing Record 36 of Set 7 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 37 of Set 7 | praya
# Processing Record 38 of Set 7 | goderich
# Processing Record 39 of Set 7 | bosaso
# Processing Record 40 of Set 7 | noumea
# Processing Record 41 of Set 7 | belyy yar
# Processing Record 42 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 43 of Set 7 | erdaojiang
# Processing Record 44 of Set 7 | kapiri mposhi
# Processing Record 45 of Set 7 | yeppoon
# Processing Record 46 of Set 7 | shingu
# Processing Record 47 of Set 7 | kasongo-lunda
# Processing Record 48 of Set 7 | luwuk
# Processing Record 49 of Set 7 | camana
# Processing Record 50 of Set 7 | damabalas
# Processing Record 1 of Set 8 | pasni
# Processing Record 2 of Set 8 | mount pleasant
# Processing Record 3 of Set 8 | saskylakh
# Processing Record 4 of Set 8 | pondicherry
# Processing Record 5 of Set 8 | kostyantynivka
# Processing Record 6 of Set 8 | cooma
# Processing Record 7 of Set 8 | antofagasta
# Processing Record 8 of Set 8 | zeya
# Processing Record 9 of Set 8 | naze
# Processing Record 10 of Set 8 | pacific grove
# Processing Record 11 of Set 8 | jacareacanga
# Processing Record 12 of Set 8 | elizabeth city
# Processing Record 13 of Set 8 | naliya
# Processing Record 14 of Set 8 | morgan city
# Processing Record 15 of Set 8 | plettenberg bay
# Processing Record 16 of Set 8 | flin flon
# Processing Record 17 of Set 8 | daxian
# City not found. Skipping...
# Processing Record 18 of Set 8 | belgrade
# Processing Record 19 of Set 8 | burica
# City not found. Skipping...
# Processing Record 20 of Set 8 | kiama
# Processing Record 21 of Set 8 | hamilton
# Processing Record 22 of Set 8 | coripata
# Processing Record 23 of Set 8 | fairbanks
# Processing Record 24 of Set 8 | bonthe
# Processing Record 25 of Set 8 | naryan-mar
# Processing Record 26 of Set 8 | ekibastuz
# Processing Record 27 of Set 8 | puteyets
# Processing Record 28 of Set 8 | ancud
# Processing Record 29 of Set 8 | taburao
# City not found. Skipping...
# Processing Record 30 of Set 8 | xiaolingwei
# Processing Record 31 of Set 8 | yumen
# Processing Record 32 of Set 8 | ikole
# City not found. Skipping...
# Processing Record 33 of Set 8 | jalu
# Processing Record 34 of Set 8 | eureka
# Processing Record 35 of Set 8 | phimai
# Processing Record 36 of Set 8 | pauini
# Processing Record 37 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 38 of Set 8 | marechal floriano
# Processing Record 39 of Set 8 | mazyr
# Processing Record 40 of Set 8 | launceston
# Processing Record 41 of Set 8 | faanui
# Processing Record 42 of Set 8 | dergachi
# Processing Record 43 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 8 | firozpur
# Processing Record 45 of Set 8 | teano
# Processing Record 46 of Set 8 | beringovskiy
# Processing Record 47 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 48 of Set 8 | namatanai
# Processing Record 49 of Set 8 | canico
# Processing Record 50 of Set 8 | yucca valley
# Processing Record 1 of Set 9 | rockport
# Processing Record 2 of Set 9 | araouane
# Processing Record 3 of Set 9 | byron bay
# Processing Record 4 of Set 9 | goure
# Processing Record 5 of Set 9 | asau
# Processing Record 6 of Set 9 | kailua
# Processing Record 7 of Set 9 | mackenzie
# Processing Record 8 of Set 9 | bukene
# Processing Record 9 of Set 9 | vila franca do campo
# Processing Record 10 of Set 9 | pangody
# Processing Record 11 of Set 9 | belize
# Processing Record 12 of Set 9 | ryotsu
# Processing Record 13 of Set 9 | maceio
# Processing Record 14 of Set 9 | ranong
# Processing Record 15 of Set 9 | la ronge
# Processing Record 16 of Set 9 | fevralsk
# City not found. Skipping...
# Processing Record 17 of Set 9 | prince rupert
# Processing Record 18 of Set 9 | constitucion
# Processing Record 19 of Set 9 | linxia
# Processing Record 20 of Set 9 | samarai
# Processing Record 21 of Set 9 | grenaa
# Processing Record 22 of Set 9 | tual
# Processing Record 23 of Set 9 | ponta delgada
# Processing Record 24 of Set 9 | gazanjyk
# Processing Record 25 of Set 9 | sao joao da barra
# Processing Record 26 of Set 9 | quepos
# Processing Record 27 of Set 9 | ishigaki
# Processing Record 28 of Set 9 | gimli
# Processing Record 29 of Set 9 | nizwa
# Processing Record 30 of Set 9 | sakete
# Processing Record 31 of Set 9 | saint-joseph
# Processing Record 32 of Set 9 | falealupo
# City not found. Skipping...
# Processing Record 33 of Set 9 | hakkari
# Processing Record 34 of Set 9 | smardioasa
# Processing Record 35 of Set 9 | saint-paul
# Processing Record 36 of Set 9 | hovd
# Processing Record 37 of Set 9 | lhokseumawe
# Processing Record 38 of Set 9 | saint-michel-des-saints
# Processing Record 39 of Set 9 | puerto del rosario
# Processing Record 40 of Set 9 | taut
# Processing Record 41 of Set 9 | namwala
# Processing Record 42 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 43 of Set 9 | manggar
# Processing Record 44 of Set 9 | qingyuan
# Processing Record 45 of Set 9 | isangel
# Processing Record 46 of Set 9 | vestmannaeyjar
# Processing Record 47 of Set 9 | manacor
# Processing Record 48 of Set 9 | maple creek
# Processing Record 49 of Set 9 | tailai
# Processing Record 50 of Set 9 | seymchan
# Processing Record 1 of Set 10 | angoram
# Processing Record 2 of Set 10 | lebyazhye
# Processing Record 3 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 4 of Set 10 | kafanchan
# Processing Record 5 of Set 10 | bulaevo
# Processing Record 6 of Set 10 | san carlos de bariloche
# Processing Record 7 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 8 of Set 10 | nehe
# Processing Record 9 of Set 10 | pismo beach
# Processing Record 10 of Set 10 | saint-honore
# Processing Record 11 of Set 10 | griffith
# Processing Record 12 of Set 10 | kakching
# Processing Record 13 of Set 10 | touros
# Processing Record 14 of Set 10 | natal
# Processing Record 15 of Set 10 | sonoita
# Processing Record 16 of Set 10 | rorvik
# Processing Record 17 of Set 10 | avera
# Processing Record 18 of Set 10 | vardo
# Processing Record 19 of Set 10 | kichera
# Processing Record 20 of Set 10 | poceirao
# Processing Record 21 of Set 10 | washougal
# Processing Record 22 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 23 of Set 10 | dalbandin
# Processing Record 24 of Set 10 | kosh-agach
# Processing Record 25 of Set 10 | rabo de peixe
# Processing Record 26 of Set 10 | ordzhonikidze
# Processing Record 27 of Set 10 | beidao
# Processing Record 28 of Set 10 | springdale
# Processing Record 29 of Set 10 | iroquois falls
# Processing Record 30 of Set 10 | benjamin constant
# Processing Record 31 of Set 10 | yaan
# Processing Record 32 of Set 10 | bhadasar
# Processing Record 33 of Set 10 | mandalgovi
# Processing Record 34 of Set 10 | tiquicheo
# Processing Record 35 of Set 10 | east london
# Processing Record 36 of Set 10 | basco
# Processing Record 37 of Set 10 | sioux lookout
# Processing Record 38 of Set 10 | dolores
# Processing Record 39 of Set 10 | champerico
# Processing Record 40 of Set 10 | kutum
# Processing Record 41 of Set 10 | ormara
# Processing Record 42 of Set 10 | cairns
# Processing Record 43 of Set 10 | karakol
# Processing Record 44 of Set 10 | lima
# Processing Record 45 of Set 10 | torbay
# Processing Record 46 of Set 10 | baglan
# Processing Record 47 of Set 10 | praia da vitoria
# Processing Record 48 of Set 10 | labuan
# Processing Record 49 of Set 10 | juba
# Processing Record 50 of Set 10 | brigantine
# Processing Record 1 of Set 11 | hamina
# Processing Record 2 of Set 11 | syumsi
# Processing Record 3 of Set 11 | chara
# Processing Record 4 of Set 11 | den helder
# Processing Record 5 of Set 11 | san cristobal
# Processing Record 6 of Set 11 | kloulklubed
# Processing Record 7 of Set 11 | melfi
# Processing Record 8 of Set 11 | paamiut
# Processing Record 9 of Set 11 | zhoukou
# Processing Record 10 of Set 11 | mangrol
# Processing Record 11 of Set 11 | dunedin
# Processing Record 12 of Set 11 | ipu
# Processing Record 13 of Set 11 | dieppe bay
# City not found. Skipping...
# Processing Record 14 of Set 11 | zherdevka
# Processing Record 15 of Set 11 | gboko
# Processing Record 16 of Set 11 | umm durman
# City not found. Skipping...
# Processing Record 17 of Set 11 | mizan teferi
# Processing Record 18 of Set 11 | kuhdasht
# Processing Record 19 of Set 11 | cockburn town
# Processing Record 20 of Set 11 | jizan
# Processing Record 21 of Set 11 | nakonde
# Processing Record 22 of Set 11 | maldonado
# Processing Record 23 of Set 11 | cascais
# Processing Record 24 of Set 11 | muzquiz
# City not found. Skipping...
# Processing Record 25 of Set 11 | peniche
# Processing Record 26 of Set 11 | issoire
# Processing Record 27 of Set 11 | panalingaan
# Processing Record 28 of Set 11 | jardim
# Processing Record 29 of Set 11 | inderborskiy
# City not found. Skipping...
# Processing Record 30 of Set 11 | salta
# Processing Record 31 of Set 11 | alice springs
# Processing Record 32 of Set 11 | ciro marina
# Processing Record 33 of Set 11 | cabedelo
# Processing Record 34 of Set 11 | windsor
# Processing Record 35 of Set 11 | kulhudhuffushi
# Processing Record 36 of Set 11 | sibolga
# Processing Record 37 of Set 11 | walvis bay
# Processing Record 38 of Set 11 | takaka
# Processing Record 39 of Set 11 | kidal
# Processing Record 40 of Set 11 | shangrao
# Processing Record 41 of Set 11 | lakselv
# Processing Record 42 of Set 11 | kandrian
# Processing Record 43 of Set 11 | sinnamary
# Processing Record 44 of Set 11 | partizanskoye
# Processing Record 45 of Set 11 | itaituba
# Processing Record 46 of Set 11 | college
# Processing Record 47 of Set 11 | tutin
# Processing Record 48 of Set 11 | kumluca
# Processing Record 49 of Set 11 | alugan
# Processing Record 50 of Set 11 | ilebo
# Processing Record 1 of Set 12 | colac
# Processing Record 2 of Set 12 | bambanglipuro
# Processing Record 3 of Set 12 | copiapo
# Processing Record 4 of Set 12 | kigoma
# Processing Record 5 of Set 12 | puerto leguizamo
# Processing Record 6 of Set 12 | pingzhuang
# Processing Record 7 of Set 12 | xiamen
# Processing Record 8 of Set 12 | victor harbor
# Processing Record 9 of Set 12 | zhenhai
# Processing Record 10 of Set 12 | aguai
# Processing Record 11 of Set 12 | chartres
# Processing Record 12 of Set 12 | camopi
# Processing Record 13 of Set 12 | zhangye
# Processing Record 14 of Set 12 | port macquarie
# Processing Record 15 of Set 12 | itoman
# Processing Record 16 of Set 12 | keetmanshoop
# Processing Record 17 of Set 12 | opoczno
# Processing Record 18 of Set 12 | sabang
# Processing Record 19 of Set 12 | charleston
# Processing Record 20 of Set 12 | kilindoni
# Processing Record 21 of Set 12 | grand gaube
# Processing Record 22 of Set 12 | haimen
# Processing Record 23 of Set 12 | tommot
# Processing Record 24 of Set 12 | talkha
# Processing Record 25 of Set 12 | svetlyy
# Processing Record 26 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 27 of Set 12 | hanmer springs
# Processing Record 28 of Set 12 | kimbe
# Processing Record 29 of Set 12 | lewisporte
# Processing Record 30 of Set 12 | inhambane
# Processing Record 31 of Set 12 | coxim
# Processing Record 32 of Set 12 | pacifica
# Processing Record 33 of Set 12 | bayir
# Processing Record 34 of Set 12 | urdoma
# Processing Record 35 of Set 12 | mareeba
# Processing Record 36 of Set 12 | portland
# Processing Record 37 of Set 12 | san juan
# Processing Record 38 of Set 12 | damietta
# Processing Record 39 of Set 12 | shakiso
# Processing Record 40 of Set 12 | asfi
# Processing Record 41 of Set 12 | huarmey
# Processing Record 42 of Set 12 | dashitou
# Processing Record 43 of Set 12 | impfondo
# Processing Record 44 of Set 12 | zhigansk
# Processing Record 45 of Set 12 | novo aripuana
# Processing Record 46 of Set 12 | yuli
# Processing Record 47 of Set 12 | karasjok
# Processing Record 48 of Set 12 | adrar
# Processing Record 49 of Set 12 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 50 of Set 12 | bardiyah
# Processing Record 1 of Set 13 | keti bandar
# Processing Record 2 of Set 13 | udachnyy
# Processing Record 3 of Set 13 | manzhouli
# Processing Record 4 of Set 13 | superior
# Processing Record 5 of Set 13 | huazolotitlan
# City not found. Skipping...
# Processing Record 6 of Set 13 | shaartuz
# City not found. Skipping...
# Processing Record 7 of Set 13 | digby
# Processing Record 8 of Set 13 | uberaba
# Processing Record 9 of Set 13 | xinyu
# Processing Record 10 of Set 13 | jiaocheng
# Processing Record 11 of Set 13 | gayny
# Processing Record 12 of Set 13 | saint-augustin
# Processing Record 13 of Set 13 | milkovo
# Processing Record 14 of Set 13 | quatre cocos
# Processing Record 15 of Set 13 | maumere
# Processing Record 16 of Set 13 | port lincoln
# Processing Record 17 of Set 13 | evensk
# Processing Record 18 of Set 13 | safwah
# City not found. Skipping...
# Processing Record 19 of Set 13 | beloha
# Processing Record 20 of Set 13 | rehoboth
# Processing Record 21 of Set 13 | kaka
# Processing Record 22 of Set 13 | shumskiy
# Processing Record 23 of Set 13 | nivala
# Processing Record 24 of Set 13 | garissa
# Processing Record 25 of Set 13 | gravdal
# Processing Record 26 of Set 13 | tsumeb
# Processing Record 27 of Set 13 | ornskoldsvik
# Processing Record 28 of Set 13 | buala
# Processing Record 29 of Set 13 | djenne
# Processing Record 30 of Set 13 | xuanwu
# Processing Record 31 of Set 13 | baruun-urt
# Processing Record 32 of Set 13 | margate
# Processing Record 33 of Set 13 | aktau
# Processing Record 34 of Set 13 | itarema
# Processing Record 35 of Set 13 | jaguaquara
# Processing Record 36 of Set 13 | waddan
# Processing Record 37 of Set 13 | fukue
# Processing Record 38 of Set 13 | karatau
# Processing Record 39 of Set 13 | gold coast
# Processing Record 40 of Set 13 | coruripe
# Processing Record 41 of Set 13 | abrau-dyurso
# Processing Record 42 of Set 13 | cubuk
# Processing Record 43 of Set 13 | sukhobezvodnoye
# Processing Record 44 of Set 13 | saint-pierre
# Processing Record 45 of Set 13 | vestbygda
# City not found. Skipping...
# Processing Record 46 of Set 13 | nhulunbuy
# Processing Record 47 of Set 13 | acapulco
# Processing Record 48 of Set 13 | dudinka
# Processing Record 49 of Set 13 | taicheng
# Processing Record 50 of Set 13 | sinjah
# City not found. Skipping...
# Processing Record 1 of Set 14 | samusu
# City not found. Skipping...
# Processing Record 2 of Set 14 | kastamonu
# Processing Record 3 of Set 14 | camacha
# Processing Record 4 of Set 14 | teguldet
# Processing Record 5 of Set 14 | srednekolymsk
# Processing Record 6 of Set 14 | nurlat
# Processing Record 7 of Set 14 | novozavedennoye
# Processing Record 8 of Set 14 | salinas
# Processing Record 9 of Set 14 | honggang
# Processing Record 10 of Set 14 | zunyi
# Processing Record 11 of Set 14 | cavan
# Processing Record 12 of Set 14 | athabasca
# Processing Record 13 of Set 14 | lagoa
# Processing Record 14 of Set 14 | richards bay
# Processing Record 15 of Set 14 | bonavista
# Processing Record 16 of Set 14 | hobyo
# Processing Record 17 of Set 14 | ondorhaan
# City not found. Skipping...
# Processing Record 18 of Set 14 | rapid valley
# Processing Record 19 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 20 of Set 14 | bom jesus da lapa
# Processing Record 21 of Set 14 | bowen
# Processing Record 22 of Set 14 | morehead
# Processing Record 23 of Set 14 | may pen
# Processing Record 24 of Set 14 | batsfjord
# Processing Record 25 of Set 14 | east retford
# Processing Record 26 of Set 14 | okhotsk
# Processing Record 27 of Set 14 | rivne
# Processing Record 28 of Set 14 | constantine
# Processing Record 29 of Set 14 | caravelas
# Processing Record 30 of Set 14 | nawalgarh
# Processing Record 31 of Set 14 | ambon
# Processing Record 32 of Set 14 | lebowakgomo
# Processing Record 33 of Set 14 | jorhat
# Processing Record 34 of Set 14 | kandy
# Processing Record 35 of Set 14 | bubaque
# Processing Record 36 of Set 14 | deputatskiy
# Processing Record 37 of Set 14 | kapit
# Processing Record 38 of Set 14 | chilca
# Processing Record 39 of Set 14 | hasaki
# Processing Record 40 of Set 14 | narsaq
# Processing Record 41 of Set 14 | goksun
# Processing Record 42 of Set 14 | khunti
# Processing Record 43 of Set 14 | santa maria
# Processing Record 44 of Set 14 | kerchevskiy
# Processing Record 45 of Set 14 | nadadores
# Processing Record 46 of Set 14 | olinda
# Processing Record 47 of Set 14 | simbahan
# Processing Record 48 of Set 14 | finnsnes
# Processing Record 49 of Set 14 | littleton
# Processing Record 50 of Set 14 | xichang
# Processing Record 1 of Set 15 | ijaki
# City not found. Skipping...
# Processing Record 2 of Set 15 | najran
# Processing Record 3 of Set 15 | koutsouras
# Processing Record 4 of Set 15 | aitape
# Processing Record 5 of Set 15 | misratah
# Processing Record 6 of Set 15 | odienne
# Processing Record 7 of Set 15 | bac lieu
# Processing Record 8 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 9 of Set 15 | teacapan
# Processing Record 10 of Set 15 | barentu
# Processing Record 11 of Set 15 | yar-sale
# Processing Record 12 of Set 15 | winslow
# Processing Record 13 of Set 15 | pong
# Processing Record 14 of Set 15 | qui nhon
# Processing Record 15 of Set 15 | xiaoweizhai
# Processing Record 16 of Set 15 | bathsheba
# Processing Record 17 of Set 15 | ngora
# Processing Record 18 of Set 15 | markova
# Processing Record 19 of Set 15 | amot
# Processing Record 20 of Set 15 | turukhansk
# Processing Record 21 of Set 15 | rio branco
# Processing Record 22 of Set 15 | subang
# Processing Record 23 of Set 15 | san pedro
# Processing Record 24 of Set 15 | knysna
# Processing Record 25 of Set 15 | qaqortoq
# Processing Record 26 of Set 15 | kuandian
# Processing Record 27 of Set 15 | san javier
# Processing Record 28 of Set 15 | binga
# Processing Record 29 of Set 15 | montego bay
# Processing Record 30 of Set 15 | san narciso
# Processing Record 31 of Set 15 | wajima
# Processing Record 32 of Set 15 | tskaltubo
# Processing Record 33 of Set 15 | kelo
# Processing Record 34 of Set 15 | awbari
# Processing Record 35 of Set 15 | sur
# Processing Record 36 of Set 15 | veraval
# Processing Record 37 of Set 15 | tabou
# Processing Record 38 of Set 15 | macapa
# Processing Record 39 of Set 15 | san jeronimo
# Processing Record 40 of Set 15 | katobu
# Processing Record 41 of Set 15 | marawi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add weather data to a new DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0               Kilembe   0.2000   30.0000     64.18        76          38
# 1             Quelimane -17.8786   36.8883     76.57        90           1
# 2             Cape Town -33.9258   18.4232     66.27        64           0
# 3  Nova Olinda Do Norte  -3.8881  -59.0942     85.50        68          93
# 4          Novopokrovka  49.8425   36.5477     39.29        68           2
# 5              Meulaboh   4.1363   96.1285     77.76        86          48
# 6               Ahipara -35.1667  173.1667     66.65        76          65
# 7          Kruisfontein -34.0033   24.7314     58.89        80          63
# 8                 Tiksi  71.6872  128.8694    -10.39       100          90
# 9                 Bluff -46.6000  168.3333     59.29        80         100
#
#    Wind Speed Country                 Date Current Description
# 0        4.43      UG  2022-03-25 19:29:57          light rain
# 1        5.50      MZ  2022-03-25 19:25:27           clear sky
# 2       18.41      ZA  2022-03-25 19:30:00           clear sky
# 3        3.60      BR  2022-03-25 19:30:01     overcast clouds
# 4        2.35      UA  2022-03-25 19:30:02           clear sky
# 5        2.10      ID  2022-03-25 19:30:03          light rain
# 6       10.54      NZ  2022-03-25 19:30:04       broken clouds
# 7        4.76      ZA  2022-03-25 19:30:05       broken clouds
# 8        4.56      RU  2022-03-25 19:30:07     overcast clouds
# 9       15.10      NZ  2022-03-25 19:30:08     overcast clouds

# %%
# Create the output File (CSV)
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a csv
city_data_df.to_csv(output_data_file, index_label="City_ID")
